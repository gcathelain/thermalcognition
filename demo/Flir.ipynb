# %%
from thermalcognition.reader import *
from thermalcognition.calibration import *
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# # Reads Flir videos

# %%
video_path = r"../data/FLIR0131.csq"

# %%
video = read_flir_video(video_path)
# Out:
# 100%|██████████| 361/361 [00:02<00:00, 136.28it/s]

# %%
frame0 = 0
plt.imshow(video[frame0], cmap="gray")
plt.colorbar()
plt.title("Temperature of frame {0}".format(frame0))
# Out:
# Text(0.5, 1.0, 'Temperature of frame 0')
